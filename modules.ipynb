# %% [markdown]
# modules and packages helps organize and reuse the code

# %%
import math as m 
import numpy as np
m.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt, pi

print(sqrt(25))
# Out:
# 5.0

# %%
radius = 12
print(pi * radius**2)
# Out:
# 452.3893421169302
