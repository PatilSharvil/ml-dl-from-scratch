# %% [markdown]
# ### Introduction to streamlit
# streamlit is an open source framework for machine learning and data science projects. It allows you to create beutiful web applications for your machine learning and data science project with simple python scripts.

# %%
import streamlit as st
import pandas as pd
import numpy as np

# Title Of Application
st.title('Hello Streamlit')
