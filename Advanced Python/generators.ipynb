# %%
def square(num): 
    for i in range(num):
        yield i ** 2

# %%
it = square(5)

for i in it: 
    print(i)
# Out:
# 25

# %%
square(7)
# Out:
# <generator object square at 0x000002728436C640>

# %%
next(square(7))
# Out:
# 49

# %%
def numbers(): 
    yield 1
    yield 2
    yield 3

# %%
iterator = numbers()

# %%
next(iterator)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 next(iterator)
#
# StopIteration:
