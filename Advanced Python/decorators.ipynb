# %%
# Function copy
# Decorators
# closures

# %%
# Function copy -> 
def welcome(): 
    return "Welcome to Advanced Python Programming"

# %%
welcome()
# Out:
# 'Welcome to Advanced Python Programming'

# %%
wel=welcome

# %%
wel
# Out:
# <function __main__.welcome()>

# %%
wel()
# Out:
# 'Welcome to Advanced Python Programming'

# %%
del welcome

# %%
wel()
# Out:
# 'Welcome to Advanced Python Programming'

# %%
# Closures -> closures means a function in a function

def main_welcome(func):
    msg='welcome'
    def sub_welcome():
        print('welcome to the advanced python course')
        func()
        print('learn this course correctly and clearly')
    return sub_welcome()

# %%
# main_welcome()

# %%
# Decorator use -> 

@main_welcome
def course_intro(): 
    print('this is a data science and ml course')
# Out:
# welcome to the advanced python course
# this is a data science and ml course
# learn this course correctly and clearly
